# %% [markdown]
# <a href="https://colab.research.google.com/github/dorrinsam/CS_Internship/blob/master/File_Opening.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import zipfile
import datetime

# %%
# Creating a simple moving average function.
def SMA_calculation(t, w):
    s = np.size(t)
    g = np.zeros(s)
    for i in range(0, s):
        if i < w-1:
            g[i] = np.NaN
        else:
            g[i] = np.mean(t[i - w + 1 : i + 1])
    return g

# %%
# Unzipping and extracting the specific csv file.
z = zipfile.ZipFile("/content/DAT_XLSX_EURUSD_M1_2018.zip")
z.extractall()

# %%
# Opening the file with Pandas package as a dataframe this time.
my_file = pd.read_excel("DAT_XLSX_EURUSD_M1_2018.xlsx", sheet_name="2018", header=None, names=["Date and Time",
                                                                                               "Open",
                                                                                               "High",
                                                                                               "Low",
                                                                                               "Close",
                                                                                               "Volume"])
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
# Adding four new columns of MA1, MA2, MA3, and MA4 to the file
# and calculating the Moving Average of close price for durations of 5, 10, 15, 30 (N = 5, N = 10, N = 15, N = 30).
my_file["MA1"] = SMA_calculation(my_file["Close"], 5)
my_file["MA2"] = my_file.rolling(window=10)["Close"].mean()
my_file["MA3"] = my_file.rolling(window=15)["Close"].mean()
my_file["MA4"] = my_file.rolling(window=30)["Close"].mean()

# %%
# Printing the outputs.
(my_file.head(40))
# Out:
#          Date and Time     Open     High      Low    Close  Volume       MA1  \
# 0  2018-01-01 17:00:00  1.20037  1.20100  1.20037  1.20100       0       NaN
# 1  2018-01-01 17:01:00  1.20083  1.20095  1.20017  1.20030       0       NaN
# 2  2018-01-01 17:02:00  1.20035  1.20043  1.20035  1.20043       0       NaN
# 3  2018-01-01 17:03:00  1.20041  1.20050  1.20031  1.20046       0       NaN
# 4  2018-01-01 17:04:00  1.20049  1.20049  1.20046  1.20048       0  1.200534
# 5  2018-01-01 17:05:00  1.20050  1.20050  1.20048  1.20048       0  1.200430
# 6  2018-01-01 17:06:00  1.20050  1.20069  1.20032  1.20048       0  1.200466
# 7  2018-01-01 17:07:00  1.20048  1.20054  1.20027  1.20050       0  1.200480
# 8  2018-01-01 17:08:00  1.20051  1.20087  1.20047  1.20087       0  1.200562
# 9  2018-01-01 17:09:00  1.20082  1.20097  1.20076  1.20094       0  1.200654
# 10 2018-01-01 17:10:00  1.20094  1.20095  1.20076  1.20077       0  1.200712
# 11 2018-01-01 17:11:00  1.20084  1.20088  1.20084  1.20088       0  1.200792
# 12 2018-01-01 17:12:00  1.20088  1.20088  1.20079  1.20079       0  1.200850
# 13 2018-01-01 17:13:00  1.20080  1.20080  1.20080  1.20080       0  1.200836
# 14 2018-01-01 17:14:00  1.20077  1.20093  1.20077  1.20093       0  1.200834
# 15 2018-01-01 17:15:00  1.20092  1.20105  1.20036  1.20036       0  1.200752
# 16 2018-01-01 17:16:00  1.20038  1.20038  1.20038  1.20038       0  1.200652
# 17 2018-01-01 17:17:00  1.20039  1.20039  1.20038  1.20038       0  1.200570
# 18 2018-01-01 17:18:00  1.20042  1.20045  1.20040  1.20045       0  1.200500
# 19 2018-01-01 17:19:00  1.20041  1.20050  1.20041  1.20050       0  1.200414
